# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("C:/Users/anime/Downloads/merged_dataframe.csv", low_memory = False)

# %%
df.head()
# Out:
#    Unnamed: 0    log_id  label_x  user_id  age  gender  residence   city  \
# 0           0  373250.0      0.0   100005  3.0     2.0       16.0  147.0
# 1           1  101100.0      0.0   100006  5.0     2.0       13.0  191.0
# 2           2  742637.0      0.0   100009  5.0     2.0       46.0  354.0
# 3           3  744753.0      0.0   100010  3.0     4.0       33.0  319.0
# 4           4  669191.0      0.0   100019  7.0     2.0       16.0  310.0
#
#    city_rank  series_dev  ...  e_ch   e_m  e_po  e_pl  e_rn  e_section  \
# 0        2.0        32.0  ...    19  1123    13  2836     1          0
# 1        4.0        32.0  ...    19   998     6   835     1          1
# 2        2.0        11.0  ...    19   508     2   407     3          0
# 3        3.0        31.0  ...    11  1361     3  2383     3          0
# 4        2.0        16.0  ...    12  1319     5  2240     2          0
#
#            e_et  label_y  cillabel  pro
# 0  202206031527       -1        -1    0
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'log_id', 'label_x', 'user_id', 'age', 'gender',
#        'residence', 'city', 'city_rank', 'series_dev', 'series_group',
#        'emui_dev', 'device_name', 'device_size', 'net_type', 'task_id',
#        'adv_id', 'creat_type_cd', 'adv_prim_id', 'inter_type_cd', 'slot_id',
#        'site_id', 'spread_app_id', 'hispace_app_tags', 'app_second_class',
#        'app_score', 'ad_click_list_v001', 'ad_click_list_v002',
#        'ad_click_list_v003', 'ad_close_list_v001', 'ad_close_list_v002',
#        'ad_close_list_v003', 'pt_d', 'u_newsCatInterestsST_x',
#        'u_refreshTimes_x', 'u_feedLifeCycle_x', 'u_phonePrice',
#        'u_browserLifeCycle', 'u_browserMode', 'u_feedLifeCycle_y',
#        'u_refreshTimes_y', 'u_newsCatInterests', 'u_newsCatDislike',
#        'u_newsCatInterestsST_y', 'u_click_ca2_news', 'i_docId', 'i_s_sourceId',
#        'i_regionEntity', 'i_cat', 'i_entities', 'i_dislikeTimes', 'i_upTimes',
# ...

# %%
df = df.drop('Unnamed: 0', axis = 1)

# %%
df.head()
# Out:
#      log_id  label_x  user_id  age  gender  residence   city  city_rank  \
# 0  373250.0      0.0   100005  3.0     2.0       16.0  147.0        2.0
# 1  101100.0      0.0   100006  5.0     2.0       13.0  191.0        4.0
# 2  742637.0      0.0   100009  5.0     2.0       46.0  354.0        2.0
# 3  744753.0      0.0   100010  3.0     4.0       33.0  319.0        3.0
# 4  669191.0      0.0   100019  7.0     2.0       16.0  310.0        2.0
#
#    series_dev  series_group  ...  e_ch   e_m  e_po  e_pl  e_rn  e_section  \
# 0        32.0           6.0  ...    19  1123    13  2836     1          0
# 1        32.0           6.0  ...    19   998     6   835     1          1
# 2        11.0           8.0  ...    19   508     2   407     3          0
# 3        31.0           3.0  ...    11  1361     3  2383     3          0
# 4        16.0           5.0  ...    12  1319     5  2240     2          0
#
#            e_et  label_y  cillabel  pro
# 0  202206031527       -1        -1    0
# ...

# %%
df.columns
# Out:
# Index(['log_id', 'label_x', 'user_id', 'age', 'gender', 'residence', 'city',
#        'city_rank', 'series_dev', 'series_group', 'emui_dev', 'device_name',
#        'device_size', 'net_type', 'task_id', 'adv_id', 'creat_type_cd',
#        'adv_prim_id', 'inter_type_cd', 'slot_id', 'site_id', 'spread_app_id',
#        'hispace_app_tags', 'app_second_class', 'app_score',
#        'ad_click_list_v001', 'ad_click_list_v002', 'ad_click_list_v003',
#        'ad_close_list_v001', 'ad_close_list_v002', 'ad_close_list_v003',
#        'pt_d', 'u_newsCatInterestsST_x', 'u_refreshTimes_x',
#        'u_feedLifeCycle_x', 'u_phonePrice', 'u_browserLifeCycle',
#        'u_browserMode', 'u_feedLifeCycle_y', 'u_refreshTimes_y',
#        'u_newsCatInterests', 'u_newsCatDislike', 'u_newsCatInterestsST_y',
#        'u_click_ca2_news', 'i_docId', 'i_s_sourceId', 'i_regionEntity',
#        'i_cat', 'i_entities', 'i_dislikeTimes', 'i_upTimes', 'i_dtype', 'e_ch',
# ...

# %%
df['log_id'].unique()
# Out:
# array([373250., 101100., 742637., ..., 549676., 309811.,     nan])

# %%
df.head()
# Out:
#      log_id  label_x  user_id  age  gender  residence   city  city_rank  \
# 0  373250.0      0.0   100005  3.0     2.0       16.0  147.0        2.0
# 1  101100.0      0.0   100006  5.0     2.0       13.0  191.0        4.0
# 2  742637.0      0.0   100009  5.0     2.0       46.0  354.0        2.0
# 3  744753.0      0.0   100010  3.0     4.0       33.0  319.0        3.0
# 4  669191.0      0.0   100019  7.0     2.0       16.0  310.0        2.0
#
#    series_dev  series_group  ...  e_ch   e_m  e_po  e_pl  e_rn  e_section  \
# 0        32.0           6.0  ...    19  1123    13  2836     1          0
# 1        32.0           6.0  ...    19   998     6   835     1          1
# 2        11.0           8.0  ...    19   508     2   407     3          0
# 3        31.0           3.0  ...    11  1361     3  2383     3          0
# 4        16.0           5.0  ...    12  1319     5  2240     2          0
#
#            e_et  label_y  cillabel  pro
# 0  202206031527       -1        -1    0
# ...

# %%
df.columns
# Out:
# Index(['log_id', 'label_x', 'user_id', 'age', 'gender', 'residence', 'city',
#        'city_rank', 'series_dev', 'series_group', 'emui_dev', 'device_name',
#        'device_size', 'net_type', 'task_id', 'adv_id', 'creat_type_cd',
#        'adv_prim_id', 'inter_type_cd', 'slot_id', 'site_id', 'spread_app_id',
#        'hispace_app_tags', 'app_second_class', 'app_score',
#        'ad_click_list_v001', 'ad_click_list_v002', 'ad_click_list_v003',
#        'ad_close_list_v001', 'ad_close_list_v002', 'ad_close_list_v003',
#        'pt_d', 'u_newsCatInterestsST_x', 'u_refreshTimes_x',
#        'u_feedLifeCycle_x', 'u_phonePrice', 'u_browserLifeCycle',
#        'u_browserMode', 'u_feedLifeCycle_y', 'u_refreshTimes_y',
#        'u_newsCatInterests', 'u_newsCatDislike', 'u_newsCatInterestsST_y',
#        'u_click_ca2_news', 'i_docId', 'i_s_sourceId', 'i_regionEntity',
#        'i_cat', 'i_entities', 'i_dislikeTimes', 'i_upTimes', 'i_dtype', 'e_ch',
# ...

# %%
df['label_x'].value_counts()
# Out:
# 0.0    58533
# 1.0     6764
# Name: label_x, dtype: int64

# %%
df.columns
# Out:
# Index(['log_id', 'label_x', 'user_id', 'age', 'gender', 'residence', 'city',
#        'city_rank', 'series_dev', 'series_group', 'emui_dev', 'device_name',
#        'device_size', 'net_type', 'task_id', 'adv_id', 'creat_type_cd',
#        'adv_prim_id', 'inter_type_cd', 'slot_id', 'site_id', 'spread_app_id',
#        'hispace_app_tags', 'app_second_class', 'app_score',
#        'ad_click_list_v001', 'ad_click_list_v002', 'ad_click_list_v003',
#        'ad_close_list_v001', 'ad_close_list_v002', 'ad_close_list_v003',
#        'pt_d', 'u_newsCatInterestsST_x', 'u_refreshTimes_x',
#        'u_feedLifeCycle_x', 'u_phonePrice', 'u_browserLifeCycle',
#        'u_browserMode', 'u_feedLifeCycle_y', 'u_refreshTimes_y',
#        'u_newsCatInterests', 'u_newsCatDislike', 'u_newsCatInterestsST_y',
#        'u_click_ca2_news', 'i_docId', 'i_s_sourceId', 'i_regionEntity',
#        'i_cat', 'i_entities', 'i_dislikeTimes', 'i_upTimes', 'i_dtype', 'e_ch',
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 180123 entries, 0 to 180122
# Data columns (total 62 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   log_id                  65297 non-null   float64
#  1   label_x                 65297 non-null   float64
#  2   user_id                 180123 non-null  int64
#  3   age                     65297 non-null   float64
#  4   gender                  65297 non-null   float64
#  5   residence               65297 non-null   float64
#  6   city                    65297 non-null   float64
#  7   city_rank               65297 non-null   float64
#  8   series_dev              65297 non-null   float64
#  9   series_group            65297 non-null   float64
#  10  emui_dev                65297 non-null   float64
#  11  device_name             65297 non-null   float64
#  12  device_size             65297 non-null   float64
# ...

# %%
df['gender']
# Out:
# 0         2.0
# 1         2.0
# 2         2.0
# 3         4.0
# 4         2.0
#          ...
# 180118    NaN
# 180119    NaN
# 180120    NaN
# 180121    NaN
# 180122    NaN
# Name: gender, Length: 180123, dtype: float64

# %%
df.head()
# Out:
#      log_id  label_x  user_id  age  gender  residence   city  city_rank  \
# 0  373250.0      0.0   100005  3.0     2.0       16.0  147.0        2.0
# 1  101100.0      0.0   100006  5.0     2.0       13.0  191.0        4.0
# 2  742637.0      0.0   100009  5.0     2.0       46.0  354.0        2.0
# 3  744753.0      0.0   100010  3.0     4.0       33.0  319.0        3.0
# 4  669191.0      0.0   100019  7.0     2.0       16.0  310.0        2.0
#
#    series_dev  series_group  ...  e_ch   e_m  e_po  e_pl  e_rn  e_section  \
# 0        32.0           6.0  ...    19  1123    13  2836     1          0
# 1        32.0           6.0  ...    19   998     6   835     1          1
# 2        11.0           8.0  ...    19   508     2   407     3          0
# 3        31.0           3.0  ...    11  1361     3  2383     3          0
# 4        16.0           5.0  ...    12  1319     5  2240     2          0
#
#            e_et  label_y  cillabel  pro
# 0  202206031527       -1        -1    0
# ...

# %%
df.head()
# Out:
#      log_id  label_x  user_id  age  gender  residence   city  city_rank  \
# 0  373250.0      0.0   100005  3.0     2.0       16.0  147.0        2.0
# 1  101100.0      0.0   100006  5.0     2.0       13.0  191.0        4.0
# 2  742637.0      0.0   100009  5.0     2.0       46.0  354.0        2.0
# 3  744753.0      0.0   100010  3.0     4.0       33.0  319.0        3.0
# 4  669191.0      0.0   100019  7.0     2.0       16.0  310.0        2.0
#
#    series_dev  series_group  ...  e_ch   e_m  e_po  e_pl  e_rn  e_section  \
# 0        32.0           6.0  ...    19  1123    13  2836     1          0
# 1        32.0           6.0  ...    19   998     6   835     1          1
# 2        11.0           8.0  ...    19   508     2   407     3          0
# 3        31.0           3.0  ...    11  1361     3  2383     3          0
# 4        16.0           5.0  ...    12  1319     5  2240     2          0
#
#            e_et  label_y  cillabel  pro
# 0  202206031527       -1        -1    0
# ...

# %%
df.columns
# Out:
# Index(['log_id', 'label_x', 'user_id', 'age', 'gender', 'residence', 'city',
#        'city_rank', 'series_dev', 'series_group', 'emui_dev', 'device_name',
#        'device_size', 'net_type', 'task_id', 'adv_id', 'creat_type_cd',
#        'adv_prim_id', 'inter_type_cd', 'slot_id', 'site_id', 'spread_app_id',
#        'hispace_app_tags', 'app_second_class', 'app_score',
#        'ad_click_list_v001', 'ad_click_list_v002', 'ad_click_list_v003',
#        'ad_close_list_v001', 'ad_close_list_v002', 'ad_close_list_v003',
#        'pt_d', 'u_newsCatInterestsST_x', 'u_refreshTimes_x',
#        'u_feedLifeCycle_x', 'u_phonePrice', 'u_browserLifeCycle',
#        'u_browserMode', 'u_feedLifeCycle_y', 'u_refreshTimes_y',
#        'u_newsCatInterests', 'u_newsCatDislike', 'u_newsCatInterestsST_y',
#        'u_click_ca2_news', 'i_docId', 'i_s_sourceId', 'i_regionEntity',
#        'i_cat', 'i_entities', 'i_dislikeTimes', 'i_upTimes', 'i_dtype', 'e_ch',
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 180123 entries, 0 to 180122
# Data columns (total 62 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   log_id                  65297 non-null   float64
#  1   label_x                 65297 non-null   float64
#  2   user_id                 180123 non-null  int64
#  3   age                     65297 non-null   float64
#  4   gender                  65297 non-null   float64
#  5   residence               65297 non-null   float64
#  6   city                    65297 non-null   float64
#  7   city_rank               65297 non-null   float64
#  8   series_dev              65297 non-null   float64
#  9   series_group            65297 non-null   float64
#  10  emui_dev                65297 non-null   float64
#  11  device_name             65297 non-null   float64
#  12  device_size             65297 non-null   float64
# ...

# %%
df['ad_click_list_v001'].value_counts()
# Out:
# 15764                            11445
# 31706                              105
# 22937                              104
# 30157                               71
# 10548                               70
#                                  ...
# 19945^13755^31467^24627^28586        1
# 28511^13899^33968^21395^13484        1
# 23769^17677^18283^34033^31126        1
# 18217^23392^21424^18792^30239        1
# 11939^29073^19184^31874^26873        1
# Name: ad_click_list_v001, Length: 48348, dtype: int64

# %%
df.columns
# Out:
# Index(['log_id', 'label_x', 'user_id', 'age', 'gender', 'residence', 'city',
#        'city_rank', 'series_dev', 'series_group', 'emui_dev', 'device_name',
#        'device_size', 'net_type', 'task_id', 'adv_id', 'creat_type_cd',
#        'adv_prim_id', 'inter_type_cd', 'slot_id', 'site_id', 'spread_app_id',
#        'hispace_app_tags', 'app_second_class', 'app_score',
#        'ad_click_list_v001', 'ad_click_list_v002', 'ad_click_list_v003',
#        'ad_close_list_v001', 'ad_close_list_v002', 'ad_close_list_v003',
#        'pt_d', 'u_newsCatInterestsST_x', 'u_refreshTimes_x',
#        'u_feedLifeCycle_x', 'u_phonePrice', 'u_browserLifeCycle',
#        'u_browserMode', 'u_feedLifeCycle_y', 'u_refreshTimes_y',
#        'u_newsCatInterests', 'u_newsCatDislike', 'u_newsCatInterestsST_y',
#        'u_click_ca2_news', 'i_docId', 'i_s_sourceId', 'i_regionEntity',
#        'i_cat', 'i_entities', 'i_dislikeTimes', 'i_upTimes', 'i_dtype', 'e_ch',
# ...

# %%
df.head()
# Out:
#      log_id  label_x  user_id  age  gender  residence   city  city_rank  \
# 0  373250.0      0.0   100005  3.0     2.0       16.0  147.0        2.0
# 1  101100.0      0.0   100006  5.0     2.0       13.0  191.0        4.0
# 2  742637.0      0.0   100009  5.0     2.0       46.0  354.0        2.0
# 3  744753.0      0.0   100010  3.0     4.0       33.0  319.0        3.0
# 4  669191.0      0.0   100019  7.0     2.0       16.0  310.0        2.0
#
#    series_dev  series_group  ...  e_ch   e_m  e_po  e_pl  e_rn  e_section  \
# 0        32.0           6.0  ...    19  1123    13  2836     1          0
# 1        32.0           6.0  ...    19   998     6   835     1          1
# 2        11.0           8.0  ...    19   508     2   407     3          0
# 3        31.0           3.0  ...    11  1361     3  2383     3          0
# 4        16.0           5.0  ...    12  1319     5  2240     2          0
#
#            e_et  label_y  cillabel  pro
# 0  202206031527       -1        -1    0
# ...

# %%
string = '13443'
string.split("^")
# Out:
# ['13443']

# %%
arr = []
df['ad_click_list_v001'] = df['ad_click_list_v001'].astype('str')
for i in range(0, len(df['ad_click_list_v001'])):
    
    ls = df['ad_click_list_v001'][i].split("^")
    arr.append(ls)

# %%
df['ad_click_list_v001'] = arr

# %%
df.columns
# Out:
# Index(['log_id', 'label_x', 'user_id', 'age', 'gender', 'residence', 'city',
#        'city_rank', 'series_dev', 'series_group', 'emui_dev', 'device_name',
#        'device_size', 'net_type', 'task_id', 'adv_id', 'creat_type_cd',
#        'adv_prim_id', 'inter_type_cd', 'slot_id', 'site_id', 'spread_app_id',
#        'hispace_app_tags', 'app_second_class', 'app_score',
#        'ad_click_list_v001', 'ad_click_list_v002', 'ad_click_list_v003',
#        'ad_close_list_v001', 'ad_close_list_v002', 'ad_close_list_v003',
#        'pt_d', 'u_newsCatInterestsST_x', 'u_refreshTimes_x',
#        'u_feedLifeCycle_x', 'u_phonePrice', 'u_browserLifeCycle',
#        'u_browserMode', 'u_feedLifeCycle_y', 'u_refreshTimes_y',
#        'u_newsCatInterests', 'u_newsCatDislike', 'u_newsCatInterestsST_y',
#        'u_click_ca2_news', 'i_docId', 'i_s_sourceId', 'i_regionEntity',
#        'i_cat', 'i_entities', 'i_dislikeTimes', 'i_upTimes', 'i_dtype', 'e_ch',
# ...

# %%
arr = []
df['ad_click_list_v002'] = df['ad_click_list_v002'].astype('str')
for i in range(0, len(df['ad_click_list_v002'])):
    
    ls = df['ad_click_list_v002'][i].split("^")
    arr.append(ls)
df['ad_click_list_v002'] = arr

# %%
arr = []
df['ad_click_list_v003'] = df['ad_click_list_v003'].astype('str')
for i in range(0, len(df['ad_click_list_v003'])):
    
    ls = df['ad_click_list_v003'][i].split("^")
    arr.append(ls)
df['ad_click_list_v003'] = arr

# %%
arr = []
df['ad_close_list_v001'] = df['ad_close_list_v001'].astype('str')
for i in range(0, len(df['ad_close_list_v001'])):
    
    ls = df['ad_close_list_v001'][i].split("^")
    arr.append(ls)
df['ad_click_list_v001'] = arr

# %%
arr = []
df['ad_close_list_v002'] = df['ad_close_list_v002'].astype('str')
for i in range(0, len(df['ad_close_list_v002'])):
    
    ls = df['ad_close_list_v002'][i].split("^")
    arr.append(ls)
df['ad_click_list_v002'] = arr

# %%
arr = []
df['ad_close_list_v003'] = df['ad_close_list_v003'].astype('str')
for i in range(0, len(df['ad_close_list_v003'])):
    
    ls = df['ad_close_list_v003'][i].split("^")
    arr.append(ls)
df['ad_click_list_v003'] = arr

# %%
df.head()
# Out:
#      log_id  label_x  user_id  age  gender  residence   city  city_rank  \
# 0  373250.0      0.0   100005  3.0     2.0       16.0  147.0        2.0
# 1  101100.0      0.0   100006  5.0     2.0       13.0  191.0        4.0
# 2  742637.0      0.0   100009  5.0     2.0       46.0  354.0        2.0
# 3  744753.0      0.0   100010  3.0     4.0       33.0  319.0        3.0
# 4  669191.0      0.0   100019  7.0     2.0       16.0  310.0        2.0
#
#    series_dev  series_group  ...  e_ch   e_m  e_po  e_pl  e_rn  e_section  \
# 0        32.0           6.0  ...    19  1123    13  2836     1          0
# 1        32.0           6.0  ...    19   998     6   835     1          1
# 2        11.0           8.0  ...    19   508     2   407     3          0
# 3        31.0           3.0  ...    11  1361     3  2383     3          0
# 4        16.0           5.0  ...    12  1319     5  2240     2          0
#
#            e_et  label_y  cillabel  pro
# 0  202206031527       -1        -1    0
# ...

# %%
df.columns
# Out:
# Index(['log_id', 'label_x', 'user_id', 'age', 'gender', 'residence', 'city',
#        'city_rank', 'series_dev', 'series_group', 'emui_dev', 'device_name',
#        'device_size', 'net_type', 'task_id', 'adv_id', 'creat_type_cd',
#        'adv_prim_id', 'inter_type_cd', 'slot_id', 'site_id', 'spread_app_id',
#        'hispace_app_tags', 'app_second_class', 'app_score',
#        'ad_click_list_v001', 'ad_click_list_v002', 'ad_click_list_v003',
#        'ad_close_list_v001', 'ad_close_list_v002', 'ad_close_list_v003',
#        'pt_d', 'u_newsCatInterestsST_x', 'u_refreshTimes_x',
#        'u_feedLifeCycle_x', 'u_phonePrice', 'u_browserLifeCycle',
#        'u_browserMode', 'u_feedLifeCycle_y', 'u_refreshTimes_y',
#        'u_newsCatInterests', 'u_newsCatDislike', 'u_newsCatInterestsST_y',
#        'u_click_ca2_news', 'i_docId', 'i_s_sourceId', 'i_regionEntity',
#        'i_cat', 'i_entities', 'i_dislikeTimes', 'i_upTimes', 'i_dtype', 'e_ch',
# ...

# %%
df.head()
# Out:
#      log_id  label_x  user_id  age  gender  residence   city  city_rank  \
# 0  373250.0      0.0   100005  3.0     2.0       16.0  147.0        2.0
# 1  101100.0      0.0   100006  5.0     2.0       13.0  191.0        4.0
# 2  742637.0      0.0   100009  5.0     2.0       46.0  354.0        2.0
# 3  744753.0      0.0   100010  3.0     4.0       33.0  319.0        3.0
# 4  669191.0      0.0   100019  7.0     2.0       16.0  310.0        2.0
#
#    series_dev  series_group  ...  e_ch   e_m  e_po  e_pl  e_rn  e_section  \
# 0        32.0           6.0  ...    19  1123    13  2836     1          0
# 1        32.0           6.0  ...    19   998     6   835     1          1
# 2        11.0           8.0  ...    19   508     2   407     3          0
# 3        31.0           3.0  ...    11  1361     3  2383     3          0
# 4        16.0           5.0  ...    12  1319     5  2240     2          0
#
#            e_et  label_y  cillabel  pro
# 0  202206031527       -1        -1    0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 180123 entries, 0 to 180122
# Data columns (total 62 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   log_id                  65297 non-null   float64
#  1   label_x                 65297 non-null   float64
#  2   user_id                 180123 non-null  int64
#  3   age                     65297 non-null   float64
#  4   gender                  65297 non-null   float64
#  5   residence               65297 non-null   float64
#  6   city                    65297 non-null   float64
#  7   city_rank               65297 non-null   float64
#  8   series_dev              65297 non-null   float64
#  9   series_group            65297 non-null   float64
#  10  emui_dev                65297 non-null   float64
#  11  device_name             65297 non-null   float64
#  12  device_size             65297 non-null   float64
# ...

# %%
df.head()
# Out:
#      log_id  label_x  user_id  age  gender  residence   city  city_rank  \
# 0  373250.0      0.0   100005  3.0     2.0       16.0  147.0        2.0
# 1  101100.0      0.0   100006  5.0     2.0       13.0  191.0        4.0
# 2  742637.0      0.0   100009  5.0     2.0       46.0  354.0        2.0
# 3  744753.0      0.0   100010  3.0     4.0       33.0  319.0        3.0
# 4  669191.0      0.0   100019  7.0     2.0       16.0  310.0        2.0
#
#    series_dev  series_group  ...  e_ch   e_m  e_po  e_pl  e_rn  e_section  \
# 0        32.0           6.0  ...    19  1123    13  2836     1          0
# 1        32.0           6.0  ...    19   998     6   835     1          1
# 2        11.0           8.0  ...    19   508     2   407     3          0
# 3        31.0           3.0  ...    11  1361     3  2383     3          0
# 4        16.0           5.0  ...    12  1319     5  2240     2          0
#
#            e_et  label_y  cillabel  pro
# 0  202206031527       -1        -1    0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 180123 entries, 0 to 180122
# Data columns (total 62 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   log_id                  65297 non-null   float64
#  1   label_x                 65297 non-null   float64
#  2   user_id                 180123 non-null  int64
#  3   age                     65297 non-null   float64
#  4   gender                  65297 non-null   float64
#  5   residence               65297 non-null   float64
#  6   city                    65297 non-null   float64
#  7   city_rank               65297 non-null   float64
#  8   series_dev              65297 non-null   float64
#  9   series_group            65297 non-null   float64
#  10  emui_dev                65297 non-null   float64
#  11  device_name             65297 non-null   float64
#  12  device_size             65297 non-null   float64
# ...

# %%
df['u_newsCatInterestsST_x'].value_counts()
# Out:
# 0                    14576
# 168                    557
# 98                     414
# 78                     235
# 112                    221
#                      ...
# 98^192^57^112^98         1
# 168^65^171^98^16         1
# 98^171^79^65^168         1
# 49^78^157^0^168          1
# 78^112^173^143^10        1
# Name: u_newsCatInterestsST_x, Length: 43996, dtype: int64

# %%
arr = []
df['u_newsCatInterestsST_x'] = df['u_newsCatInterestsST_x'].astype('str')
for i in range(0, len(df['age'])):
    
    ls = df['u_newsCatInterestsST_x'][i].split("^")
    arr.append(ls)
    
df['u_newsCatInterestsST_x'] = arr

# %%
df.head()
# Out:
#      log_id  label_x  user_id  age  gender  residence   city  city_rank  \
# 0  373250.0      0.0   100005  3.0     2.0       16.0  147.0        2.0
# 1  101100.0      0.0   100006  5.0     2.0       13.0  191.0        4.0
# 2  742637.0      0.0   100009  5.0     2.0       46.0  354.0        2.0
# 3  744753.0      0.0   100010  3.0     4.0       33.0  319.0        3.0
# 4  669191.0      0.0   100019  7.0     2.0       16.0  310.0        2.0
#
#    series_dev  series_group  ...  e_ch   e_m  e_po  e_pl  e_rn  e_section  \
# 0        32.0           6.0  ...    19  1123    13  2836     1          0
# 1        32.0           6.0  ...    19   998     6   835     1          1
# 2        11.0           8.0  ...    19   508     2   407     3          0
# 3        31.0           3.0  ...    11  1361     3  2383     3          0
# 4        16.0           5.0  ...    12  1319     5  2240     2          0
#
#            e_et  label_y  cillabel  pro
# 0  202206031527       -1        -1    0
# ...

# %%
df['u_newsCatInterests'].value_counts()
# Out:
# 0                      46423
# 168                     7486
# 98                      2172
# 112                     1758
# 65                      1535
#                        ...
# 199^25^65^169^173          1
# 123^194^219^168^114        1
# 104^98^168^114^74          1
# 0^78^8^157^112             1
# 65^191^10                  1
# Name: u_newsCatInterests, Length: 91113, dtype: int64

# %%
arr = []
df['u_newsCatInterests'] = df['u_newsCatInterests'].astype('str')
for i in range(0, len(df['u_newsCatInterests'])):
    
    ls = df['u_newsCatInterests'][i].split("^")
    arr.append(ls)
    
df['u_newsCatInterests'] = arr

# %%
arr = []
df['u_newsCatInterests'] = df['u_newsCatInterests'].astype('str')
for i in range(0, len(df['u_newsCatInterests'])):
    
    ls = df['u_newsCatInterests'][i].split("^")
    arr.append(ls)
    
df['u_newsCatInterests'] = arr

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 180123 entries, 0 to 180122
# Data columns (total 62 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   log_id                  65297 non-null   float64
#  1   label_x                 65297 non-null   float64
#  2   user_id                 180123 non-null  int64
#  3   age                     65297 non-null   float64
#  4   gender                  65297 non-null   float64
#  5   residence               65297 non-null   float64
#  6   city                    65297 non-null   float64
#  7   city_rank               65297 non-null   float64
#  8   series_dev              65297 non-null   float64
#  9   series_group            65297 non-null   float64
#  10  emui_dev                65297 non-null   float64
#  11  device_name             65297 non-null   float64
#  12  device_size             65297 non-null   float64
# ...

# %%
df['u_newsCatDislike'].value_counts()
# Out:
# 0                 178844
# 65                    89
# 98                    41
# 168                   39
# 86                    33
#                    ...
# 53^147^151^119         1
# 56^65^136^158          1
# 0^3^0^65^52            1
# 48                     1
# 71^45^173              1
# Name: u_newsCatDislike, Length: 438, dtype: int64

# %%
arr = []
df['u_newsCatDislike'] = df['u_newsCatDislike'].astype('str')
for i in range(0, len(df['u_newsCatDislike'])):
    
    ls = df['u_newsCatDislike'][i].split("^")
    arr.append(ls)
    
df['u_newsCatDislike'] = arr

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 180123 entries, 0 to 180122
# Data columns (total 62 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   log_id                  65297 non-null   float64
#  1   label_x                 65297 non-null   float64
#  2   user_id                 180123 non-null  int64
#  3   age                     65297 non-null   float64
#  4   gender                  65297 non-null   float64
#  5   residence               65297 non-null   float64
#  6   city                    65297 non-null   float64
#  7   city_rank               65297 non-null   float64
#  8   series_dev              65297 non-null   float64
#  9   series_group            65297 non-null   float64
#  10  emui_dev                65297 non-null   float64
#  11  device_name             65297 non-null   float64
#  12  device_size             65297 non-null   float64
# ...

# %%
arr = []
df['u_newsCatInterestsST_y'] = df['u_newsCatInterestsST_y'].astype('str')
for i in range(0, len(df['age'])):
    
    ls = df['u_newsCatInterestsST_y'][i].split("^")
    arr.append(ls)
    
df['u_newsCatInterestsST_y'] = arr

# %%
arr = []
df['u_click_ca2_news'] = df['u_click_ca2_news'].astype('str')
for i in range(0, len(df['u_click_ca2_news'])):
    
    ls = df['u_click_ca2_news'][i].split("^")
    arr.append(ls)
    
df['u_click_ca2_news'] = arr

# %%
df['app_score'].value_counts()
# Out:
# 10.0    56266
# 0.0      9001
# 6.0        30
# Name: app_score, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 180123 entries, 0 to 180122
# Data columns (total 68 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   log_id                  65297 non-null   float64
#  1   label_x                 65297 non-null   float64
#  2   user_id                 180123 non-null  int64
#  3   age                     65297 non-null   float64
#  4   gender                  65297 non-null   float64
#  5   residence               65297 non-null   float64
#  6   city                    65297 non-null   float64
#  7   city_rank               65297 non-null   float64
#  8   series_dev              65297 non-null   float64
#  9   series_group            65297 non-null   float64
#  10  emui_dev                65297 non-null   float64
#  11  device_name             65297 non-null   float64
#  12  device_size             65297 non-null   float64
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 180123 entries, 0 to 180122
# Data columns (total 62 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   log_id                  65297 non-null   float64
#  1   label_x                 65297 non-null   float64
#  2   user_id                 180123 non-null  int64
#  3   age                     65297 non-null   float64
#  4   gender                  65297 non-null   float64
#  5   residence               65297 non-null   float64
#  6   city                    65297 non-null   float64
#  7   city_rank               65297 non-null   float64
#  8   series_dev              65297 non-null   float64
#  9   series_group            65297 non-null   float64
#  10  emui_dev                65297 non-null   float64
#  11  device_name             65297 non-null   float64
#  12  device_size             65297 non-null   float64
# ...

# %%
df['pt_d'] = pd.to_datetime(df['pt_d'], format='%Y%m%d%H%M')
df['e_et'] = pd.to_datetime(df['e_et'], format='%Y%m%d%H%M')

# %%
df['p_year'] = df['pt_d'].dt.year
df['e_year'] = df['e_et'].dt.year

# %%
df['p_hour'] = df['pt_d'].dt.hour
df['e_hour'] = df['e_et'].dt.hour

# %%
df['p_month'] = df['pt_d'].dt.month
df['e_month'] = df['e_et'].dt.month

# %%
df['p_day'] = df['pt_d'].dt.dayofweek
df['e_day'] = df['e_et'].dt.dayofweek

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 180123 entries, 0 to 180122
# Data columns (total 70 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   log_id                  65297 non-null   float64
#  1   label_x                 65297 non-null   float64
#  2   user_id                 180123 non-null  int64
#  3   age                     65297 non-null   float64
#  4   gender                  65297 non-null   float64
#  5   residence               65297 non-null   float64
#  6   city                    65297 non-null   float64
#  7   city_rank               65297 non-null   float64
#  8   series_dev              65297 non-null   float64
#  9   series_group            65297 non-null   float64
#  10  emui_dev                65297 non-null   float64
#  11  device_name             65297 non-null   float64
#  12  device_size             65297 non-null   float64
# ...

# %%
df = df.drop(['e_et', 'pt_d'], axis = 1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 180123 entries, 0 to 180122
# Data columns (total 68 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   log_id                  65297 non-null   float64
#  1   label_x                 65297 non-null   float64
#  2   user_id                 180123 non-null  int64
#  3   age                     65297 non-null   float64
#  4   gender                  65297 non-null   float64
#  5   residence               65297 non-null   float64
#  6   city                    65297 non-null   float64
#  7   city_rank               65297 non-null   float64
#  8   series_dev              65297 non-null   float64
#  9   series_group            65297 non-null   float64
#  10  emui_dev                65297 non-null   float64
#  11  device_name             65297 non-null   float64
#  12  device_size             65297 non-null   float64
# ...

# %%
df.to_csv("feature engineered data.csv")

# %%
df.columns
# Out:
# Index(['log_id', 'label_x', 'user_id', 'age', 'gender', 'residence', 'city',
#        'city_rank', 'series_dev', 'series_group', 'emui_dev', 'device_name',
#        'device_size', 'net_type', 'task_id', 'adv_id', 'creat_type_cd',
#        'adv_prim_id', 'inter_type_cd', 'slot_id', 'site_id', 'spread_app_id',
#        'hispace_app_tags', 'app_second_class', 'app_score',
#        'ad_click_list_v001', 'ad_click_list_v002', 'ad_click_list_v003',
#        'ad_close_list_v001', 'ad_close_list_v002', 'ad_close_list_v003',
#        'u_newsCatInterestsST_x', 'u_refreshTimes_x', 'u_feedLifeCycle_x',
#        'u_phonePrice', 'u_browserLifeCycle', 'u_browserMode',
#        'u_feedLifeCycle_y', 'u_refreshTimes_y', 'u_newsCatInterests',
#        'u_newsCatDislike', 'u_newsCatInterestsST_y', 'u_click_ca2_news',
#        'i_docId', 'i_s_sourceId', 'i_regionEntity', 'i_cat', 'i_entities',
#        'i_dislikeTimes', 'i_upTimes', 'i_dtype', 'e_ch', 'e_m', 'e_po', 'e_pl',
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 180123 entries, 0 to 180122
# Data columns (total 68 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   log_id                  65297 non-null   float64
#  1   label_x                 65297 non-null   float64
#  2   user_id                 180123 non-null  int64
#  3   age                     65297 non-null   float64
#  4   gender                  65297 non-null   float64
#  5   residence               65297 non-null   float64
#  6   city                    65297 non-null   float64
#  7   city_rank               65297 non-null   float64
#  8   series_dev              65297 non-null   float64
#  9   series_group            65297 non-null   float64
#  10  emui_dev                65297 non-null   float64
#  11  device_name             65297 non-null   float64
#  12  device_size             65297 non-null   float64
# ...

# %%
df['i_entities'].value_counts()
# Out:
# 1e276cf0530a7bf9fee2c7314e5a6042b0d0e50ddca1d98b66377f8dabe70a65^4743b8cc88b72c924c7498fe24da1c19b3091c2bf98de52bfcc060caa379c196^be63363a9be70a0ddcf57a1ec8a4c2cbc4a212b5da6ed604d7039e9d90077895^4eca0123583593faca821741c895fde29086172803419dcb91fd3737c788b65e^4f6852f2a9d056b75d9a865a5eaf52018b555be828f509732d520ba2caf3a777    2793
# 4722943cf29924bbd0c81cfd695d229d0157444a4d9989e45e9c3655f9b0d206^2a21362d122afa537b8c84ebf354988bca4728745aa50a6e2bf8680af7775a9f^5ac86c8d5b532ea0e793352895f5c5cd05274ae41fa86953ad87921517b28d0d^031facc6569ff88b8f473291c1435fcb2740e17039a8d91f142c1b91a67c47aa                                                                     1301
# ...

# %%
df[]

# %%
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer
from sklearn.linear_model import LinearRegression

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 180123 entries, 0 to 180122
# Data columns (total 49 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   age                     65297 non-null   float64
#  1   gender                  65297 non-null   float64
#  2   residence               65297 non-null   float64
#  3   city                    65297 non-null   float64
#  4   city_rank               65297 non-null   float64
#  5   series_dev              65297 non-null   float64
#  6   series_group            65297 non-null   float64
#  7   emui_dev                65297 non-null   float64
#  8   device_name             65297 non-null   float64
#  9   device_size             65297 non-null   float64
#  10  net_type                65297 non-null   float64
#  11  creat_type_cd           65297 non-null   float64
#  12  inter_type_cd           65297 non-null   float64
# ...

# %%
df.columns
# Out:
# Index(['log_id', 'label_x', 'user_id', 'age', 'gender', 'residence', 'city',
#        'city_rank', 'series_dev', 'series_group', 'emui_dev', 'device_name',
#        'device_size', 'net_type', 'task_id', 'adv_id', 'creat_type_cd',
#        'adv_prim_id', 'inter_type_cd', 'slot_id', 'site_id', 'spread_app_id',
#        'hispace_app_tags', 'app_second_class', 'app_score',
#        'ad_click_list_v001', 'ad_click_list_v002', 'ad_click_list_v003',
#        'ad_close_list_v001', 'ad_close_list_v002', 'ad_close_list_v003',
#        'u_newsCatInterestsST_x', 'u_refreshTimes_x', 'u_feedLifeCycle_x',
#        'u_phonePrice', 'u_browserLifeCycle', 'u_browserMode',
#        'u_feedLifeCycle_y', 'u_refreshTimes_y', 'u_newsCatInterests',
#        'u_newsCatDislike', 'u_newsCatInterestsST_y', 'u_click_ca2_news',
#        'i_docId', 'i_s_sourceId', 'i_regionEntity', 'i_cat', 'i_entities',
#        'i_dislikeTimes', 'i_upTimes', 'i_dtype', 'e_ch', 'e_m', 'e_po', 'e_pl',
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 180123 entries, 0 to 180122
# Data columns (total 68 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   log_id                  65297 non-null   float64
#  1   label_x                 65297 non-null   float64
#  2   user_id                 180123 non-null  int64
#  3   age                     65297 non-null   float64
#  4   gender                  65297 non-null   float64
#  5   residence               65297 non-null   float64
#  6   city                    65297 non-null   float64
#  7   city_rank               65297 non-null   float64
#  8   series_dev              65297 non-null   float64
#  9   series_group            65297 non-null   float64
#  10  emui_dev                65297 non-null   float64
#  11  device_name             65297 non-null   float64
#  12  device_size             65297 non-null   float64
# ...

# %%
missing = ['log_id', 'age', 'gender', 'residence', 'city', 'city_rank', 'series_dev','task_id', 'adv_id',
       'series_group', 'emui_dev', 'device_name', 'device_size', 'net_type',
       'creat_type_cd', 'inter_type_cd', 'hispace_app_tags','label_x', 'slot_id', 'site_id','spread_app_id', 'adv_prim_id',
       'app_second_class', 'app_score','u_refreshTimes_x', 'u_feedLifeCycle_x', 'p_year', 'p_month', 'p_day', 'p_hour']

# %%
predictors = ['e_year', 'e_month', 'e_day', 'e_hour', 'u_phonePrice',
       'u_browserLifeCycle', 'u_browserMode', 'u_feedLifeCycle_y',
       'u_refreshTimes_y',  'i_dislikeTimes', 'i_upTimes', 'i_dtype',
       'e_ch', 'e_m', 'e_po', 'e_pl', 'e_rn', 'e_section', 'label_y',
       'cillabel', 'pro', ]

# %%
imputer = IterativeImputer(estimator=LinearRegression())

# %%
imputed_data = imputer.fit_transform(df[predictors + missing])

# %%
df[missing] = imputed_data[:, -len(missing):]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 180123 entries, 0 to 180122
# Data columns (total 68 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   log_id                  180123 non-null  float64
#  1   label_x                 180123 non-null  float64
#  2   user_id                 180123 non-null  int64
#  3   age                     180123 non-null  float64
#  4   gender                  180123 non-null  float64
#  5   residence               180123 non-null  float64
#  6   city                    180123 non-null  float64
#  7   city_rank               180123 non-null  float64
#  8   series_dev              180123 non-null  float64
#  9   series_group            180123 non-null  float64
#  10  emui_dev                180123 non-null  float64
#  11  device_name             180123 non-null  float64
#  12  device_size             180123 non-null  float64
# ...

# %%
df.to_csv("feature engineered data.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 180123 entries, 0 to 180122
# Data columns (total 68 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   log_id                  180123 non-null  float64
#  1   label_x                 180123 non-null  float64
#  2   user_id                 180123 non-null  int64
#  3   age                     180123 non-null  float64
#  4   gender                  180123 non-null  float64
#  5   residence               180123 non-null  float64
#  6   city                    180123 non-null  float64
#  7   city_rank               180123 non-null  float64
#  8   series_dev              180123 non-null  float64
#  9   series_group            180123 non-null  float64
#  10  emui_dev                180123 non-null  float64
#  11  device_name             180123 non-null  float64
#  12  device_size             180123 non-null  float64
# ...

# %%
df['i_entities'].fillna("No Entity Source Available", inplace = True)
