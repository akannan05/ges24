# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("C:/Users/anime/Downloads/merged_dataframe.csv", low_memory = False)

# %%
df.head()
# Out:
#    Unnamed: 0    log_id  label_x  user_id  age  gender  residence   city  \
# 0           0  373250.0      0.0   100005  3.0     2.0       16.0  147.0
# 1           1  101100.0      0.0   100006  5.0     2.0       13.0  191.0
# 2           2  742637.0      0.0   100009  5.0     2.0       46.0  354.0
# 3           3  744753.0      0.0   100010  3.0     4.0       33.0  319.0
# 4           4  669191.0      0.0   100019  7.0     2.0       16.0  310.0
#
#    city_rank  series_dev  ...  e_ch   e_m  e_po  e_pl  e_rn  e_section  \
# 0        2.0        32.0  ...    19  1123    13  2836     1          0
# 1        4.0        32.0  ...    19   998     6   835     1          1
# 2        2.0        11.0  ...    19   508     2   407     3          0
# 3        3.0        31.0  ...    11  1361     3  2383     3          0
# 4        2.0        16.0  ...    12  1319     5  2240     2          0
#
#            e_et  label_y  cillabel  pro
# 0  202206031527       -1        -1    0
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'log_id', 'label_x', 'user_id', 'age', 'gender',
#        'residence', 'city', 'city_rank', 'series_dev', 'series_group',
#        'emui_dev', 'device_name', 'device_size', 'net_type', 'task_id',
#        'adv_id', 'creat_type_cd', 'adv_prim_id', 'inter_type_cd', 'slot_id',
#        'site_id', 'spread_app_id', 'hispace_app_tags', 'app_second_class',
#        'app_score', 'ad_click_list_v001', 'ad_click_list_v002',
#        'ad_click_list_v003', 'ad_close_list_v001', 'ad_close_list_v002',
#        'ad_close_list_v003', 'pt_d', 'u_newsCatInterestsST_x',
#        'u_refreshTimes_x', 'u_feedLifeCycle_x', 'u_phonePrice',
#        'u_browserLifeCycle', 'u_browserMode', 'u_feedLifeCycle_y',
#        'u_refreshTimes_y', 'u_newsCatInterests', 'u_newsCatDislike',
#        'u_newsCatInterestsST_y', 'u_click_ca2_news', 'i_docId', 'i_s_sourceId',
#        'i_regionEntity', 'i_cat', 'i_entities', 'i_dislikeTimes', 'i_upTimes',
# ...

# %%
df = df.drop('Unnamed: 0', axis = 1)

# %%
df.head()
# Out:
#      log_id  label_x  user_id  age  gender  residence   city  city_rank  \
# 0  373250.0      0.0   100005  3.0     2.0       16.0  147.0        2.0
# 1  101100.0      0.0   100006  5.0     2.0       13.0  191.0        4.0
# 2  742637.0      0.0   100009  5.0     2.0       46.0  354.0        2.0
# 3  744753.0      0.0   100010  3.0     4.0       33.0  319.0        3.0
# 4  669191.0      0.0   100019  7.0     2.0       16.0  310.0        2.0
#
#    series_dev  series_group  ...  e_ch   e_m  e_po  e_pl  e_rn  e_section  \
# 0        32.0           6.0  ...    19  1123    13  2836     1          0
# 1        32.0           6.0  ...    19   998     6   835     1          1
# 2        11.0           8.0  ...    19   508     2   407     3          0
# 3        31.0           3.0  ...    11  1361     3  2383     3          0
# 4        16.0           5.0  ...    12  1319     5  2240     2          0
#
#            e_et  label_y  cillabel  pro
# 0  202206031527       -1        -1    0
# ...

# %%
df.columns
# Out:
# Index(['log_id', 'label_x', 'user_id', 'age', 'gender', 'residence', 'city',
#        'city_rank', 'series_dev', 'series_group', 'emui_dev', 'device_name',
#        'device_size', 'net_type', 'task_id', 'adv_id', 'creat_type_cd',
#        'adv_prim_id', 'inter_type_cd', 'slot_id', 'site_id', 'spread_app_id',
#        'hispace_app_tags', 'app_second_class', 'app_score',
#        'ad_click_list_v001', 'ad_click_list_v002', 'ad_click_list_v003',
#        'ad_close_list_v001', 'ad_close_list_v002', 'ad_close_list_v003',
#        'pt_d', 'u_newsCatInterestsST_x', 'u_refreshTimes_x',
#        'u_feedLifeCycle_x', 'u_phonePrice', 'u_browserLifeCycle',
#        'u_browserMode', 'u_feedLifeCycle_y', 'u_refreshTimes_y',
#        'u_newsCatInterests', 'u_newsCatDislike', 'u_newsCatInterestsST_y',
#        'u_click_ca2_news', 'i_docId', 'i_s_sourceId', 'i_regionEntity',
#        'i_cat', 'i_entities', 'i_dislikeTimes', 'i_upTimes', 'i_dtype', 'e_ch',
# ...

# %%
df['log_id'].unique()
# Out:
# array([373250., 101100., 742637., ..., 549676., 309811.,     nan])

# %%
df = df.drop(['log_id', 'user_id', 'task_id', 'adv_id', 'slot_id', 'adv_prim_id'], axis = 1)

# %%
df.head()
# Out:
#    label_x  age  gender  residence   city  city_rank  series_dev  \
# 0      0.0  3.0     2.0       16.0  147.0        2.0        32.0
# 1      0.0  5.0     2.0       13.0  191.0        4.0        32.0
# 2      0.0  5.0     2.0       46.0  354.0        2.0        11.0
# 3      0.0  3.0     4.0       33.0  319.0        3.0        31.0
# 4      0.0  7.0     2.0       16.0  310.0        2.0        16.0
#
#    series_group  emui_dev  device_name  ...  e_ch   e_m  e_po  e_pl  e_rn  \
# 0           6.0      35.0        312.0  ...    19  1123    13  2836     1
# 1           6.0      20.0        229.0  ...    19   998     6   835     1
# 2           8.0      32.0        301.0  ...    19   508     2   407     3
# 3           3.0      20.0        122.0  ...    11  1361     3  2383     3
# 4           5.0      35.0        324.0  ...    12  1319     5  2240     2
#
#    e_section          e_et  label_y  cillabel pro
# 0          0  202206031527       -1        -1   0
# ...

# %%
df.columns
# Out:
# Index(['label_x', 'age', 'gender', 'residence', 'city', 'city_rank',
#        'series_dev', 'series_group', 'emui_dev', 'device_name', 'device_size',
#        'net_type', 'creat_type_cd', 'inter_type_cd', 'site_id',
#        'spread_app_id', 'hispace_app_tags', 'app_second_class', 'app_score',
#        'ad_click_list_v001', 'ad_click_list_v002', 'ad_click_list_v003',
#        'ad_close_list_v001', 'ad_close_list_v002', 'ad_close_list_v003',
#        'pt_d', 'u_newsCatInterestsST_x', 'u_refreshTimes_x',
#        'u_feedLifeCycle_x', 'u_phonePrice', 'u_browserLifeCycle',
#        'u_browserMode', 'u_feedLifeCycle_y', 'u_refreshTimes_y',
#        'u_newsCatInterests', 'u_newsCatDislike', 'u_newsCatInterestsST_y',
#        'u_click_ca2_news', 'i_docId', 'i_s_sourceId', 'i_regionEntity',
#        'i_cat', 'i_entities', 'i_dislikeTimes', 'i_upTimes', 'i_dtype', 'e_ch',
#        'e_m', 'e_po', 'e_pl', 'e_rn', 'e_section', 'e_et', 'label_y',
#        'cillabel', 'pro'],
# ...

# %%
df['label_x'].value_counts()
# Out:
# 0.0    58533
# 1.0     6764
# Name: label_x, dtype: int64

# %%
df = df.drop('label_x', axis = 1)

# %%
df.columns
# Out:
# Index(['age', 'gender', 'residence', 'city', 'city_rank', 'series_dev',
#        'series_group', 'emui_dev', 'device_name', 'device_size', 'net_type',
#        'creat_type_cd', 'inter_type_cd', 'site_id', 'spread_app_id',
#        'hispace_app_tags', 'app_second_class', 'app_score',
#        'ad_click_list_v001', 'ad_click_list_v002', 'ad_click_list_v003',
#        'ad_close_list_v001', 'ad_close_list_v002', 'ad_close_list_v003',
#        'pt_d', 'u_newsCatInterestsST_x', 'u_refreshTimes_x',
#        'u_feedLifeCycle_x', 'u_phonePrice', 'u_browserLifeCycle',
#        'u_browserMode', 'u_feedLifeCycle_y', 'u_refreshTimes_y',
#        'u_newsCatInterests', 'u_newsCatDislike', 'u_newsCatInterestsST_y',
#        'u_click_ca2_news', 'i_docId', 'i_s_sourceId', 'i_regionEntity',
#        'i_cat', 'i_entities', 'i_dislikeTimes', 'i_upTimes', 'i_dtype', 'e_ch',
#        'e_m', 'e_po', 'e_pl', 'e_rn', 'e_section', 'e_et', 'label_y',
#        'cillabel', 'pro'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 180123 entries, 0 to 180122
# Data columns (total 55 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   age                     65297 non-null   float64
#  1   gender                  65297 non-null   float64
#  2   residence               65297 non-null   float64
#  3   city                    65297 non-null   float64
#  4   city_rank               65297 non-null   float64
#  5   series_dev              65297 non-null   float64
#  6   series_group            65297 non-null   float64
#  7   emui_dev                65297 non-null   float64
#  8   device_name             65297 non-null   float64
#  9   device_size             65297 non-null   float64
#  10  net_type                65297 non-null   float64
#  11  creat_type_cd           65297 non-null   float64
#  12  inter_type_cd           65297 non-null   float64
# ...

# %%
df['gender']
# Out:
# 0         2.0
# 1         2.0
# 2         2.0
# 3         4.0
# 4         2.0
#          ...
# 180118    NaN
# 180119    NaN
# 180120    NaN
# 180121    NaN
# 180122    NaN
# Name: gender, Length: 180123, dtype: float64

# %%
df = df.drop('site_id', axis = 1)

# %%
df.head()
# Out:
#    age  gender  residence   city  city_rank  series_dev  series_group  \
# 0  3.0     2.0       16.0  147.0        2.0        32.0           6.0
# 1  5.0     2.0       13.0  191.0        4.0        32.0           6.0
# 2  5.0     2.0       46.0  354.0        2.0        11.0           8.0
# 3  3.0     4.0       33.0  319.0        3.0        31.0           3.0
# 4  7.0     2.0       16.0  310.0        2.0        16.0           5.0
#
#    emui_dev  device_name  device_size  ...  e_ch   e_m  e_po  e_pl  e_rn  \
# 0      35.0        312.0       2117.0  ...    19  1123    13  2836     1
# 1      20.0        229.0       1545.0  ...    19   998     6   835     1
# 2      32.0        301.0       1186.0  ...    19   508     2   407     3
# 3      20.0        122.0       2117.0  ...    11  1361     3  2383     3
# 4      35.0        324.0       2401.0  ...    12  1319     5  2240     2
#
#    e_section          e_et label_y cillabel pro
# 0          0  202206031527      -1       -1   0
# ...

# %%
df = df.drop('spread_app_id', axis = 1)

# %%
df.head()
# Out:
#    age  gender  residence   city  city_rank  series_dev  series_group  \
# 0  3.0     2.0       16.0  147.0        2.0        32.0           6.0
# 1  5.0     2.0       13.0  191.0        4.0        32.0           6.0
# 2  5.0     2.0       46.0  354.0        2.0        11.0           8.0
# 3  3.0     4.0       33.0  319.0        3.0        31.0           3.0
# 4  7.0     2.0       16.0  310.0        2.0        16.0           5.0
#
#    emui_dev  device_name  device_size  ...  e_ch   e_m  e_po  e_pl  e_rn  \
# 0      35.0        312.0       2117.0  ...    19  1123    13  2836     1
# 1      20.0        229.0       1545.0  ...    19   998     6   835     1
# 2      32.0        301.0       1186.0  ...    19   508     2   407     3
# 3      20.0        122.0       2117.0  ...    11  1361     3  2383     3
# 4      35.0        324.0       2401.0  ...    12  1319     5  2240     2
#
#    e_section          e_et label_y cillabel pro
# 0          0  202206031527      -1       -1   0
# ...

# %%
df.columns
# Out:
# Index(['age', 'gender', 'residence', 'city', 'city_rank', 'series_dev',
#        'series_group', 'emui_dev', 'device_name', 'device_size', 'net_type',
#        'creat_type_cd', 'inter_type_cd', 'hispace_app_tags',
#        'app_second_class', 'app_score', 'ad_click_list_v001',
#        'ad_click_list_v002', 'ad_click_list_v003', 'ad_close_list_v001',
#        'ad_close_list_v002', 'ad_close_list_v003', 'pt_d',
#        'u_newsCatInterestsST_x', 'u_refreshTimes_x', 'u_feedLifeCycle_x',
#        'u_phonePrice', 'u_browserLifeCycle', 'u_browserMode',
#        'u_feedLifeCycle_y', 'u_refreshTimes_y', 'u_newsCatInterests',
#        'u_newsCatDislike', 'u_newsCatInterestsST_y', 'u_click_ca2_news',
#        'i_docId', 'i_s_sourceId', 'i_regionEntity', 'i_cat', 'i_entities',
#        'i_dislikeTimes', 'i_upTimes', 'i_dtype', 'e_ch', 'e_m', 'e_po', 'e_pl',
#        'e_rn', 'e_section', 'e_et', 'label_y', 'cillabel', 'pro'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 180123 entries, 0 to 180122
# Data columns (total 53 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   age                     65297 non-null   float64
#  1   gender                  65297 non-null   float64
#  2   residence               65297 non-null   float64
#  3   city                    65297 non-null   float64
#  4   city_rank               65297 non-null   float64
#  5   series_dev              65297 non-null   float64
#  6   series_group            65297 non-null   float64
#  7   emui_dev                65297 non-null   float64
#  8   device_name             65297 non-null   float64
#  9   device_size             65297 non-null   float64
#  10  net_type                65297 non-null   float64
#  11  creat_type_cd           65297 non-null   float64
#  12  inter_type_cd           65297 non-null   float64
# ...

# %%
df['ad_click_list_v001'].value_counts()
# Out:
# 15764                            11445
# 31706                              105
# 22937                              104
# 30157                               71
# 10548                               70
#                                  ...
# 19945^13755^31467^24627^28586        1
# 28511^13899^33968^21395^13484        1
# 23769^17677^18283^34033^31126        1
# 18217^23392^21424^18792^30239        1
# 11939^29073^19184^31874^26873        1
# Name: ad_click_list_v001, Length: 48348, dtype: int64

# %%
df['total_ads_clicked'] = df['ad_click_list_v001']

# %%
df = df.drop(['ad_click_list_v001', 'ad_click_list_v002', 'ad_click_list_v003'], axis = 1)

# %%
df.head()
# Out:
#    age  gender  residence   city  city_rank  series_dev  series_group  \
# 0  3.0     2.0       16.0  147.0        2.0        32.0           6.0
# 1  5.0     2.0       13.0  191.0        4.0        32.0           6.0
# 2  5.0     2.0       46.0  354.0        2.0        11.0           8.0
# 3  3.0     4.0       33.0  319.0        3.0        31.0           3.0
# 4  7.0     2.0       16.0  310.0        2.0        16.0           5.0
#
#    emui_dev  device_name  device_size  ...   e_m  e_po  e_pl  e_rn  e_section  \
# 0      35.0        312.0       2117.0  ...  1123    13  2836     1          0
# 1      20.0        229.0       1545.0  ...   998     6   835     1          1
# 2      32.0        301.0       1186.0  ...   508     2   407     3          0
# 3      20.0        122.0       2117.0  ...  1361     3  2383     3          0
# 4      35.0        324.0       2401.0  ...  1319     5  2240     2          0
#
#            e_et label_y cillabel pro              total_ads_clicked
# ...

# %%
string = '13443'
string.split("^")
# Out:
# ['13443']

# %%
arr = []
df['total_ads_clicked'] = df['total_ads_clicked'].astype('str')
for i in range(0, len(df['total_ads_clicked'])):
    
    ls = df['total_ads_clicked'][i].split("^")
    arr.append(len(ls))

# %%
df['total_ads_clicked'] = arr

# %%
df.head()
# Out:
#    age  gender  residence   city  city_rank  series_dev  series_group  \
# 0  3.0     2.0       16.0  147.0        2.0        32.0           6.0
# 1  5.0     2.0       13.0  191.0        4.0        32.0           6.0
# 2  5.0     2.0       46.0  354.0        2.0        11.0           8.0
# 3  3.0     4.0       33.0  319.0        3.0        31.0           3.0
# 4  7.0     2.0       16.0  310.0        2.0        16.0           5.0
#
#    emui_dev  device_name  device_size  ...   e_m  e_po  e_pl  e_rn  e_section  \
# 0      35.0        312.0       2117.0  ...  1123    13  2836     1          0
# 1      20.0        229.0       1545.0  ...   998     6   835     1          1
# 2      32.0        301.0       1186.0  ...   508     2   407     3          0
# 3      20.0        122.0       2117.0  ...  1361     3  2383     3          0
# 4      35.0        324.0       2401.0  ...  1319     5  2240     2          0
#
#            e_et label_y cillabel pro  total_ads_clicked
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 180123 entries, 0 to 180122
# Data columns (total 51 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   age                     65297 non-null   float64
#  1   gender                  65297 non-null   float64
#  2   residence               65297 non-null   float64
#  3   city                    65297 non-null   float64
#  4   city_rank               65297 non-null   float64
#  5   series_dev              65297 non-null   float64
#  6   series_group            65297 non-null   float64
#  7   emui_dev                65297 non-null   float64
#  8   device_name             65297 non-null   float64
#  9   device_size             65297 non-null   float64
#  10  net_type                65297 non-null   float64
#  11  creat_type_cd           65297 non-null   float64
#  12  inter_type_cd           65297 non-null   float64
# ...

# %%
df['total_ads_closed'] = df['ad_close_list_v001']

# %%
df = df.drop(['ad_close_list_v001', 'ad_close_list_v002', 'ad_close_list_v003'], axis = 1)

# %%
arr = []
df['total_ads_closed'] = df['total_ads_closed'].astype('str')
for i in range(0, len(df['total_ads_closed'])):
    
    ls = df['total_ads_closed'][i].split("^")
    arr.append(len(ls))

# %%
df['total_ads_closed'] = arr

# %%
df.head()
# Out:
#    age  gender  residence   city  city_rank  series_dev  series_group  \
# 0  3.0     2.0       16.0  147.0        2.0        32.0           6.0
# 1  5.0     2.0       13.0  191.0        4.0        32.0           6.0
# 2  5.0     2.0       46.0  354.0        2.0        11.0           8.0
# 3  3.0     4.0       33.0  319.0        3.0        31.0           3.0
# 4  7.0     2.0       16.0  310.0        2.0        16.0           5.0
#
#    emui_dev  device_name  device_size  ...  e_po  e_pl  e_rn  e_section  \
# 0      35.0        312.0       2117.0  ...    13  2836     1          0
# 1      20.0        229.0       1545.0  ...     6   835     1          1
# 2      32.0        301.0       1186.0  ...     2   407     3          0
# 3      20.0        122.0       2117.0  ...     3  2383     3          0
# 4      35.0        324.0       2401.0  ...     5  2240     2          0
#
#            e_et  label_y  cillabel pro  total_ads_clicked  total_ads_closed
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 180123 entries, 0 to 180122
# Data columns (total 49 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   age                     65297 non-null   float64
#  1   gender                  65297 non-null   float64
#  2   residence               65297 non-null   float64
#  3   city                    65297 non-null   float64
#  4   city_rank               65297 non-null   float64
#  5   series_dev              65297 non-null   float64
#  6   series_group            65297 non-null   float64
#  7   emui_dev                65297 non-null   float64
#  8   device_name             65297 non-null   float64
#  9   device_size             65297 non-null   float64
#  10  net_type                65297 non-null   float64
#  11  creat_type_cd           65297 non-null   float64
#  12  inter_type_cd           65297 non-null   float64
# ...

# %%
df = df.drop(['i_entities', 'i_cat', 'i_regionEntity', 'i_s_sourceId', 'i_docId'], axis = 1)

# %%
df.head()
# Out:
#    age  gender  residence   city  city_rank  series_dev  series_group  \
# 0  3.0     2.0       16.0  147.0        2.0        32.0           6.0
# 1  5.0     2.0       13.0  191.0        4.0        32.0           6.0
# 2  5.0     2.0       46.0  354.0        2.0        11.0           8.0
# 3  3.0     4.0       33.0  319.0        3.0        31.0           3.0
# 4  7.0     2.0       16.0  310.0        2.0        16.0           5.0
#
#    emui_dev  device_name  device_size  ...  e_po  e_pl  e_rn  e_section  \
# 0      35.0        312.0       2117.0  ...    13  2836     1          0
# 1      20.0        229.0       1545.0  ...     6   835     1          1
# 2      32.0        301.0       1186.0  ...     2   407     3          0
# 3      20.0        122.0       2117.0  ...     3  2383     3          0
# 4      35.0        324.0       2401.0  ...     5  2240     2          0
#
#            e_et  label_y  cillabel pro  total_ads_clicked  total_ads_closed
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 180123 entries, 0 to 180122
# Data columns (total 44 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   age                     65297 non-null   float64
#  1   gender                  65297 non-null   float64
#  2   residence               65297 non-null   float64
#  3   city                    65297 non-null   float64
#  4   city_rank               65297 non-null   float64
#  5   series_dev              65297 non-null   float64
#  6   series_group            65297 non-null   float64
#  7   emui_dev                65297 non-null   float64
#  8   device_name             65297 non-null   float64
#  9   device_size             65297 non-null   float64
#  10  net_type                65297 non-null   float64
#  11  creat_type_cd           65297 non-null   float64
#  12  inter_type_cd           65297 non-null   float64
# ...

# %%
df['u_newsCatInterestsST_x'].value_counts()
# Out:
# 0                    14576
# 168                    557
# 98                     414
# 78                     235
# 112                    221
#                      ...
# 98^192^57^112^98         1
# 168^65^171^98^16         1
# 98^171^79^65^168         1
# 49^78^157^0^168          1
# 78^112^173^143^10        1
# Name: u_newsCatInterestsST_x, Length: 43996, dtype: int64

# %%
arr = []
df['u_newsCatInterestsST_x'] = df['u_newsCatInterestsST_x'].astype('str')
for i in range(0, len(df['total_ads_closed'])):
    
    ls = df['u_newsCatInterestsST_x'][i].split("^")
    arr.append(len(ls))
    
df['u_newsCatInterestsST_x'] = arr

# %%
df.head()
# Out:
#    age  gender  residence   city  city_rank  series_dev  series_group  \
# 0  3.0     2.0       16.0  147.0        2.0        32.0           6.0
# 1  5.0     2.0       13.0  191.0        4.0        32.0           6.0
# 2  5.0     2.0       46.0  354.0        2.0        11.0           8.0
# 3  3.0     4.0       33.0  319.0        3.0        31.0           3.0
# 4  7.0     2.0       16.0  310.0        2.0        16.0           5.0
#
#    emui_dev  device_name  device_size  ...  e_po  e_pl  e_rn  e_section  \
# 0      35.0        312.0       2117.0  ...    13  2836     1          0
# 1      20.0        229.0       1545.0  ...     6   835     1          1
# 2      32.0        301.0       1186.0  ...     2   407     3          0
# 3      20.0        122.0       2117.0  ...     3  2383     3          0
# 4      35.0        324.0       2401.0  ...     5  2240     2          0
#
#            e_et  label_y  cillabel  pro  total_ads_clicked  total_ads_closed
# ...

# %%
df['u_newsCatInterests'].value_counts()
# Out:
# 0                      46423
# 168                     7486
# 98                      2172
# 112                     1758
# 65                      1535
#                        ...
# 199^25^65^169^173          1
# 123^194^219^168^114        1
# 104^98^168^114^74          1
# 0^78^8^157^112             1
# 65^191^10                  1
# Name: u_newsCatInterests, Length: 91113, dtype: int64

# %%
arr = []
df['u_newsCatInterests'] = df['u_newsCatInterests'].astype('str')
for i in range(0, len(df['u_newsCatInterests'])):
    
    ls = df['u_newsCatInterests'][i].split("^")
    arr.append(len(ls))
    
df['u_newsCatInterests'] = arr

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 180123 entries, 0 to 180122
# Data columns (total 44 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   age                     65297 non-null   float64
#  1   gender                  65297 non-null   float64
#  2   residence               65297 non-null   float64
#  3   city                    65297 non-null   float64
#  4   city_rank               65297 non-null   float64
#  5   series_dev              65297 non-null   float64
#  6   series_group            65297 non-null   float64
#  7   emui_dev                65297 non-null   float64
#  8   device_name             65297 non-null   float64
#  9   device_size             65297 non-null   float64
#  10  net_type                65297 non-null   float64
#  11  creat_type_cd           65297 non-null   float64
#  12  inter_type_cd           65297 non-null   float64
# ...

# %%
df['u_newsCatDislike'].value_counts()
# Out:
# 0                 178844
# 65                    89
# 98                    41
# 168                   39
# 86                    33
#                    ...
# 53^147^151^119         1
# 56^65^136^158          1
# 0^3^0^65^52            1
# 48                     1
# 71^45^173              1
# Name: u_newsCatDislike, Length: 438, dtype: int64

# %%
arr = []
df['u_newsCatDislike'] = df['u_newsCatDislike'].astype('str')
for i in range(0, len(df['u_newsCatDislike'])):
    
    ls = df['u_newsCatDislike'][i].split("^")
    arr.append(len(ls))
    
df['u_newsCatDislike'] = arr

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 180123 entries, 0 to 180122
# Data columns (total 44 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   age                     65297 non-null   float64
#  1   gender                  65297 non-null   float64
#  2   residence               65297 non-null   float64
#  3   city                    65297 non-null   float64
#  4   city_rank               65297 non-null   float64
#  5   series_dev              65297 non-null   float64
#  6   series_group            65297 non-null   float64
#  7   emui_dev                65297 non-null   float64
#  8   device_name             65297 non-null   float64
#  9   device_size             65297 non-null   float64
#  10  net_type                65297 non-null   float64
#  11  creat_type_cd           65297 non-null   float64
#  12  inter_type_cd           65297 non-null   float64
# ...

# %%
arr = []
df['u_newsCatInterestsST_y'] = df['u_newsCatInterestsST_y'].astype('str')
for i in range(0, len(df['total_ads_closed'])):
    
    ls = df['u_newsCatInterestsST_y'][i].split("^")
    arr.append(len(ls))
    
df['u_newsCatInterestsST_y'] = arr

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 180123 entries, 0 to 180122
# Data columns (total 44 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   age                     65297 non-null   float64
#  1   gender                  65297 non-null   float64
#  2   residence               65297 non-null   float64
#  3   city                    65297 non-null   float64
#  4   city_rank               65297 non-null   float64
#  5   series_dev              65297 non-null   float64
#  6   series_group            65297 non-null   float64
#  7   emui_dev                65297 non-null   float64
#  8   device_name             65297 non-null   float64
#  9   device_size             65297 non-null   float64
#  10  net_type                65297 non-null   float64
#  11  creat_type_cd           65297 non-null   float64
#  12  inter_type_cd           65297 non-null   float64
# ...

# %%
df = df.drop('u_click_ca2_news', axis = 1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 180123 entries, 0 to 180122
# Data columns (total 43 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   age                     65297 non-null   float64
#  1   gender                  65297 non-null   float64
#  2   residence               65297 non-null   float64
#  3   city                    65297 non-null   float64
#  4   city_rank               65297 non-null   float64
#  5   series_dev              65297 non-null   float64
#  6   series_group            65297 non-null   float64
#  7   emui_dev                65297 non-null   float64
#  8   device_name             65297 non-null   float64
#  9   device_size             65297 non-null   float64
#  10  net_type                65297 non-null   float64
#  11  creat_type_cd           65297 non-null   float64
#  12  inter_type_cd           65297 non-null   float64
# ...

# %%
df['pt_d'] = pd.to_datetime(df['pt_d'], format='%Y%m%d%H%M')
df['e_et'] = pd.to_datetime(df['e_et'], format='%Y%m%d%H%M')

# %%
df['p_year'] = df['pt_d'].dt.year
df['e_year'] = df['e_et'].dt.year

# %%
df['p_hour'] = df['pt_d'].dt.hour
df['e_hour'] = df['e_et'].dt.hour

# %%
df['p_month'] = df['pt_d'].dt.month
df['e_month'] = df['e_et'].dt.month

# %%
df['p_day'] = df['pt_d'].dt.dayofweek
df['e_day'] = df['e_et'].dt.dayofweek

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 180123 entries, 0 to 180122
# Data columns (total 51 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   age                     65297 non-null   float64
#  1   gender                  65297 non-null   float64
#  2   residence               65297 non-null   float64
#  3   city                    65297 non-null   float64
#  4   city_rank               65297 non-null   float64
#  5   series_dev              65297 non-null   float64
#  6   series_group            65297 non-null   float64
#  7   emui_dev                65297 non-null   float64
#  8   device_name             65297 non-null   float64
#  9   device_size             65297 non-null   float64
#  10  net_type                65297 non-null   float64
#  11  creat_type_cd           65297 non-null   float64
#  12  inter_type_cd           65297 non-null   float64
# ...

# %%
df = df.drop(['e_et', 'pt_d'], axis = 1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 180123 entries, 0 to 180122
# Data columns (total 49 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   age                     65297 non-null   float64
#  1   gender                  65297 non-null   float64
#  2   residence               65297 non-null   float64
#  3   city                    65297 non-null   float64
#  4   city_rank               65297 non-null   float64
#  5   series_dev              65297 non-null   float64
#  6   series_group            65297 non-null   float64
#  7   emui_dev                65297 non-null   float64
#  8   device_name             65297 non-null   float64
#  9   device_size             65297 non-null   float64
#  10  net_type                65297 non-null   float64
#  11  creat_type_cd           65297 non-null   float64
#  12  inter_type_cd           65297 non-null   float64
# ...

# %%
df.to_csv("feature engineered data.csv")

# %%
df.head()
# Out:
#    age  gender  residence   city  city_rank  series_dev  series_group  \
# 0  3.0     2.0       16.0  147.0        2.0        32.0           6.0
# 1  5.0     2.0       13.0  191.0        4.0        32.0           6.0
# 2  5.0     2.0       46.0  354.0        2.0        11.0           8.0
# 3  3.0     4.0       33.0  319.0        3.0        31.0           3.0
# 4  7.0     2.0       16.0  310.0        2.0        16.0           5.0
#
#    emui_dev  device_name  device_size  ...  total_ads_clicked  \
# 0      35.0        312.0       2117.0  ...                  4
# 1      20.0        229.0       1545.0  ...                  5
# 2      32.0        301.0       1186.0  ...                  3
# 3      20.0        122.0       2117.0  ...                  3
# 4      35.0        324.0       2401.0  ...                  5
#
#    total_ads_closed  p_year  e_year  p_hour  e_hour  p_month  e_month  p_day  \
# 0                 1  2022.0    2022     3.0      15      6.0        6    4.0
# ...

# %%
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer
from sklearn.linear_model import LinearRegression

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 180123 entries, 0 to 180122
# Data columns (total 49 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   age                     65297 non-null   float64
#  1   gender                  65297 non-null   float64
#  2   residence               65297 non-null   float64
#  3   city                    65297 non-null   float64
#  4   city_rank               65297 non-null   float64
#  5   series_dev              65297 non-null   float64
#  6   series_group            65297 non-null   float64
#  7   emui_dev                65297 non-null   float64
#  8   device_name             65297 non-null   float64
#  9   device_size             65297 non-null   float64
#  10  net_type                65297 non-null   float64
#  11  creat_type_cd           65297 non-null   float64
#  12  inter_type_cd           65297 non-null   float64
# ...

# %%
df.columns
# Out:
# Index(['age', 'gender', 'residence', 'city', 'city_rank', 'series_dev',
#        'series_group', 'emui_dev', 'device_name', 'device_size', 'net_type',
#        'creat_type_cd', 'inter_type_cd', 'hispace_app_tags',
#        'app_second_class', 'app_score', 'u_newsCatInterestsST_x',
#        'u_refreshTimes_x', 'u_feedLifeCycle_x', 'u_phonePrice',
#        'u_browserLifeCycle', 'u_browserMode', 'u_feedLifeCycle_y',
#        'u_refreshTimes_y', 'u_newsCatInterests', 'u_newsCatDislike',
#        'u_newsCatInterestsST_y', 'i_dislikeTimes', 'i_upTimes', 'i_dtype',
#        'e_ch', 'e_m', 'e_po', 'e_pl', 'e_rn', 'e_section', 'label_y',
#        'cillabel', 'pro', 'total_ads_clicked', 'total_ads_closed', 'p_year',
#        'e_year', 'p_hour', 'e_hour', 'p_month', 'e_month', 'p_day', 'e_day'],
#       dtype='object')

# %%
missing = ['age', 'gender', 'residence', 'city', 'city_rank', 'series_dev',
       'series_group', 'emui_dev', 'device_name', 'device_size', 'net_type',
       'creat_type_cd', 'inter_type_cd', 'hispace_app_tags',
       'app_second_class', 'app_score','u_refreshTimes_x', 'u_feedLifeCycle_x', 'p_year', 'p_month', 'p_day', 'p_hour']

# %%
predictors = ['u_newsCatInterestsST_x', 'e_year', 'e_month', 'e_day', 'e_hour', 'u_phonePrice',
       'u_browserLifeCycle', 'u_browserMode', 'u_feedLifeCycle_y',
       'u_refreshTimes_y', 'u_newsCatInterests', 'u_newsCatDislike',
       'u_newsCatInterestsST_y', 'i_dislikeTimes', 'i_upTimes', 'i_dtype',
       'e_ch', 'e_m', 'e_po', 'e_pl', 'e_rn', 'e_section', 'label_y',
       'cillabel', 'pro', 'total_ads_clicked', 'total_ads_closed']

# %%
imputer = IterativeImputer(estimator=LinearRegression())

# %%
imputed_data = imputer.fit_transform(df[predictors + missing])

# %%
df[missing] = imputed_data[:, -len(missing):]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 180123 entries, 0 to 180122
# Data columns (total 49 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   age                     180123 non-null  float64
#  1   gender                  180123 non-null  float64
#  2   residence               180123 non-null  float64
#  3   city                    180123 non-null  float64
#  4   city_rank               180123 non-null  float64
#  5   series_dev              180123 non-null  float64
#  6   series_group            180123 non-null  float64
#  7   emui_dev                180123 non-null  float64
#  8   device_name             180123 non-null  float64
#  9   device_size             180123 non-null  float64
#  10  net_type                180123 non-null  float64
#  11  creat_type_cd           180123 non-null  float64
#  12  inter_type_cd           180123 non-null  float64
# ...

# %%
df.to_csv("feature engineered data.csv")

# %%
from sklearn.model_selection import train_test_split

# %%
y = df['label_y']

# %%
y = y.replace(-1, 0)

# %%
y.value_counts()
# Out:
# 0    165673
# 1     14450
# Name: label_y, dtype: int64

# %%
X = df.drop('label_y', axis = 1)

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.25, random_state=42)

# %%
X_train
# Out:
#              age    gender  residence       city  city_rank  series_dev  \
# 133781  5.072285  2.523254  26.659367  275.40625   3.100586   22.333829
# 76041   3.535190  2.302246  25.520190  275.84375   3.027344   17.773200
# 41630   6.000000  4.000000  33.000000  319.00000   3.000000   27.000000
# 158927  6.159584  2.311584  26.796921  265.46875   3.155762   27.301075
# 28640   5.000000  2.000000  45.000000  311.00000   2.000000   34.000000
# ...          ...       ...        ...        ...        ...         ...
# 119879  5.521921  2.360291  26.112208  274.50000   3.176758   27.217416
# 103694  5.023848  2.503845  26.380582  276.65625   3.449219   21.796074
# 131932  5.012386  2.309998  26.026652  276.37500   3.105957   25.313214
# 146867  5.014586  2.406372  26.337532  270.65625   3.079102   24.479757
# 121958  4.209160  2.432190  26.217516  274.46875   3.089844   18.072535
#
#         series_group   emui_dev  device_name  device_size  ...  \
# ...

# %%
from sklearn.ensemble import RandomForestClassifier
rf_model = RandomForestClassifier(n_estimators=100)
rf_model.fit(X_train, y_train)
# Out:
# RandomForestClassifier()

# %%
predictions = rf_model.predict(X_test)

# %%
from sklearn.metrics import classification_report, confusion_matrix

# %%
print(classification_report(predictions, y_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.99      0.99     41925
#            1       0.87      1.00      0.93      3106
#
#     accuracy                           0.99     45031
#    macro avg       0.93      0.99      0.96     45031
# weighted avg       0.99      0.99      0.99     45031

# %%
from sklearn.metrics import ConfusionMatrixDisplay

# %%
conf_matrix_one = confusion_matrix(y_test, predictions)

# %%
ConfusionMatrixDisplay(conf_matrix_one).plot()
plt.title("Confusion Matrix (1 = Potential Customer, 0 = Not a Potential Customer)")
# Out:
# Text(0.5, 1.0, 'Confusion Matrix (1 = Potential Customer, 0 = Not a Potential Customer)')

# %%
y_probs = rf_model.predict_proba(X_test)[:, 1]

# %%
import matplotlib.pyplot as plt

# %%
from sklearn.metrics import precision_recall_curve
precision, recall, thresholds = precision_recall_curve(y_test, y_probs)
fig, ax = plt.subplots()
ax.plot(recall, precision, color='purple')

ax.set_title('Precision-Recall Curve')
ax.set_ylabel('Precision')
ax.set_xlabel('Recall')

#display plot
plt.show()

# %%
from sklearn.metrics import roc_curve
from sklearn import metrics
fpr, tpr, _ = metrics.roc_curve(y_test, y_probs)
roc_auc = metrics.auc(fpr, tpr)
plt.figure()
plt.plot(fpr, tpr, color='darkorange', lw=2, label=f'AUC = {roc_auc:.2f}')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend(loc='lower right')
plt.show()

# %%
from imblearn.over_sampling import RandomOverSampler
from collections import Counter
oversample = RandomOverSampler(sampling_strategy='minority')
X_over, y_over = oversample.fit_resample(X, y)
print("Oversampled class distribution:", Counter(y_over))
# Out:
# Oversampled class distribution: Counter({0: 165673, 1: 165673})

# %%
X_train_over, X_test_over, y_train_over, y_test_over = train_test_split(
    X_over, y_over, test_size=0.25, random_state=42)

# %%
from sklearn.ensemble import RandomForestClassifier
rf_model_over = RandomForestClassifier(n_estimators=100)
rf_model_over.fit(X_train_over, y_train_over)
# Out:
# RandomForestClassifier()

# %%
predictions_over = rf_model_over.predict(X_test_over)

# %%
final_predictions = rf_model_over.predict(X_test)

# %%
print(classification_report(predictions_over, y_test_over))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     41367
#            1       1.00      1.00      1.00     41470
#
#     accuracy                           1.00     82837
#    macro avg       1.00      1.00      1.00     82837
# weighted avg       1.00      1.00      1.00     82837

# %%
print(classification_report(final_predictions, y_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     41441
#            1       1.00      1.00      1.00      3590
#
#     accuracy                           1.00     45031
#    macro avg       1.00      1.00      1.00     45031
# weighted avg       1.00      1.00      1.00     45031

# %%
conf_matrix_two = confusion_matrix(y_test, final_predictions)

# %%
ConfusionMatrixDisplay(conf_matrix_two).plot()
plt.title("Confusion Matrix (1 = Potential Customer, 0 = Not a Potential Customer)")
# Out:
# Text(0.5, 1.0, 'Confusion Matrix (1 = Potential Customer, 0 = Not a Potential Customer)')

# %%
y_score_over = rf_model_over.predict_proba(X_test)[:, 1]

# %%
from sklearn.metrics import precision_recall_curve
precision, recall, thresholds = precision_recall_curve(y_test, y_score_over)
fig, ax = plt.subplots()
ax.plot(recall, precision, color='purple')

ax.set_title('Precision-Recall Curve')
ax.set_ylabel('Precision')
ax.set_xlabel('Recall')

#display plot
plt.show()

# %%
from sklearn.metrics import roc_curve
from sklearn import metrics
fpr, tpr, _ = metrics.roc_curve(y_test, y_score_over)
roc_auc = metrics.auc(fpr, tpr)
plt.figure()
plt.plot(fpr, tpr, color='darkorange', lw=2, label=f'AUC = {roc_auc:.2f}')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend(loc='lower right')
plt.show()

# %%
feat_importances = pd.Series(rf_model_over.feature_importances_, index=X.columns)
feat_importances.nlargest(15).plot(kind='barh', color='skyblue')
plt.title("Feature Importance Plot for Random Forest Model")
plt.ylabel("Feature")
plt.gca().invert_yaxis() 
plt.xlabel("Importance")
plt.figure(figsize=(10, 10))
