# %%
import ctgan

# %%
from ctgan import conditional
help(ctgan)
# Out:
# Help on package ctgan:
#
# NAME
#     ctgan - Top-level package for _ctgan.
#
# PACKAGE CONTENTS
#     _conditional
#     _data
#     _demo
#     _models
#     _sampler
#     _synthesizer
#     _transformer
#     conditional
#     data
#     demo
#     models
#     sampler
#     synthesizer
#     transformer
#
# DATA
#     __email__ = 'dailabmit@gmail.com'
#
# VERSION
#     0.2.1
#
# AUTHOR
#     MIT Data To AI Lab
#
# FILE
#     c:\users\anime\anaconda3\envs\tensor\lib\site-packages\ctgan\__init__.py

# %%
from ctgan import transformer

# %%
help(transformer)
# Out:
# Help on module ctgan.transformer in ctgan:
#
# NAME
#     ctgan.transformer
#
# FILE
#     c:\users\anime\anaconda3\envs\tensor\lib\site-packages\ctgan\transformer.py

# %%
from ctgan import demo,models, synthesizer
from sklearn.datasets import load_breast_cancer
data = load_breast_cancer()
import matplotlib.pyplot as plt
plt.hist(data.data[0])
# Names of the columns that are discrete
# Out:
# (array([28.,  0.,  0.,  0.,  1.,  0.,  0.,  0.,  0.,  1.]),
#  array([6.19300000e-03, 2.01905574e+02, 4.03804954e+02, 6.05704335e+02,
#         8.07603716e+02, 1.00950310e+03, 1.21140248e+03, 1.41330186e+03,
#         1.61520124e+03, 1.81710062e+03, 2.01900000e+03]),
#  <BarContainer object of 10 artists>)

# %%
help(synthesizer)
# Out:
# Help on module ctgan.synthesizer in ctgan:
#
# NAME
#     ctgan.synthesizer
#
# CLASSES
#     builtins.object
#         CTGANSynthesizer
#         EarlyStopping
#
#     class CTGANSynthesizer(builtins.object)
#      |  Conditional Table GAN Synthesizer.
#      |
#      |  This is the core class of the CTGAN project, where the different components
#      |  are orchestrated together.
#      |
#      |  For more details about the process, please check the [Modeling Tabular data using
#      |  Conditional GAN](https://arxiv.org/abs/1907.00503) paper.
#      |
#      |  Args:
#      |      embedding_dim (int):
#      |          Size of the random sample passed to the Generator. Defaults to 128.
#      |      gen_dim (tuple or list of ints):
#      |          Size of the output samples for each one of the Residuals. A Resiudal Layer
#      |          will be created for each one of the values provided. Defaults to (256, 256).
#      |      dis_dim (tuple or list of ints):
# ...

# %%
for x in data.data:
    print(len(x))
# Out:
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# ...

# %%
import seaborn as sns
tips = sns.load_dataset("tips")

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
help(sampler)
# Out:
# Help on module ctgan.sampler in ctgan:
#
# NAME
#     ctgan.sampler
#
# CLASSES
#     builtins.object
#         Sampler
#
#     class Sampler(builtins.object)
#      |  docstring for Sampler.
#      |
#      |  Methods defined here:
#      |
#      |  __init__(self, data, output_info)
#      |      Initialize self.  See help(type(self)) for accurate signature.
#      |
#      |  sample(self, n, col, opt)
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors defined here:
#      |
#      |  __dict__
#      |      dictionary for instance variables (if defined)
#      |
#      |  __weakref__
#      |      list of weak references to the object (if defined)
#
# FILE
#     c:\users\anime\anaconda3\envs\tensor\lib\site-packages\ctgan\sampler.py

# %%
import seaborn as sns
discrete_columns = [
    'sex',
    'smoker',
    'day',
    'time',
    'size'
]
#arr = []
#arr = np.array(arr)
#sampler = sampler.Sampler(tips, tips)
ctgan = synthesizer.CTGANSynthesizer()
print(type(ctgan))
ctgan.fit(tips, discrete_columns, epochs=10)
#ctgan
#ctsynthetic_data = ctgan.sample(1000)
#ctgan.fit(data, discrete_columns)
# Out:
# <class 'ctgan.synthesizer.CTGANSynthesizer'>
# Fitting CTGAN transformers for each column:   0%|                                                | 0/7 [00:00<?, ?it/s]C:\Users\anime\anaconda3\envs\tensor\lib\site-packages\sklearn\utils\validation.py:72: FutureWarning: Pass n_components=10 as keyword args. From version 1.0 (renaming of 0.25) passing these as positional arguments will result in an error
#   "will result in an error", FutureWarning)
# Fitting CTGAN transformers for each column:  14%|█████▋                                  | 1/7 [00:00<00:01,  4.05it/s]C:\Users\anime\anaconda3\envs\tensor\lib\site-packages\sklearn\utils\validation.py:72: FutureWarning: Pass n_components=10 as keyword args. From version 1.0 (renaming of 0.25) passing these as positional arguments will result in an error
#   "will result in an error", FutureWarning)
# Fitting CTGAN transformers for each column: 100%|████████████████████████████████████████| 7/7 [00:00<00:00, 15.93it/s]

# %%
type(ctgan)
# Out:
# ctgan.synthesizer.CTGANSynthesizer

# %%
fake_data = ctgan.sample(244)

# %%
fake_data
# Out:
#     total_bill      tip     sex smoker   day    time size
# 0      22.9809  5.08655    Male     No   Sun  Dinner    3
# 1       9.1059  4.72675    Male     No   Sat   Lunch    1
# 2      37.5894  14.6208    Male    Yes   Sun   Lunch    3
# 3      3.70122  4.12562    Male    Yes   Fri   Lunch    4
# 4      15.0715  4.64471  Female     No   Sun  Dinner    5
# ..         ...      ...     ...    ...   ...     ...  ...
# 239    14.2083   9.8509    Male     No  Thur   Lunch    5
# 240    28.5167  1.56821  Female     No   Sun  Dinner    3
# 241    21.8609  2.98322    Male     No   Sat   Lunch    2
# 242    26.5513  3.90713  Female     No   Sat  Dinner    3
# 243    19.5718  4.64028    Male    Yes   Sun  Dinner    4
#
# [244 rows x 7 columns]

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
plt.hist(tips['total_bill'])
# Out:
# (array([ 7., 42., 68., 51., 31., 19., 12.,  7.,  3.,  4.]),
#  array([ 3.07 ,  7.844, 12.618, 17.392, 22.166, 26.94 , 31.714, 36.488,
#         41.262, 46.036, 50.81 ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(fake_data['total_bill'])
# Out:
# (array([ 4.,  7., 33., 40., 54., 32., 24., 22., 17., 11.]),
#  array([-3.820777334725271, 1.8774425465291307, 7.5756624277835325,
#         13.273882309037933, 18.972102190292336, 24.67032207154674,
#         30.368541952801138, 36.06676183405554, 41.76498171530994,
#         47.463201596564346, 53.16142147781875], dtype=object),
#  <BarContainer object of 10 artists>)

# %%
def compute_vector_similarity(a,b):
    
    return np.dot(a, b) / np.linalg.norm(a) / np.linalg.norm(b)

# %%
print(compute_vector_similarity(np.array(tips['total_bill']), np.array(fake_data['total_bill'])))
# Out:
# 0.8222140717299736

# %%
print(compute_vector_similarity(np.array(tips['tip']), np.array(fake_data['tip'])))
# Out:
# 0.7994736562919866

# %%
print(compute_vector_similarity(np.array(tips['size']), np.array(fake_data['s'])))
